# %% [markdown]
# # Feature Extractor

# %%
import tensorflow as tf
tf.random.set_seed(221)

import matplotlib.pyplot as plt
from PIL import Image
import torch

extract_feature = True

# %% [markdown]
# Pickle

# %%
def unpickle(file):
    import pickle
    with open(file, 'rb') as fo:
        dict = pickle.load(fo, encoding='bytes')
    return dict

# %% [markdown]
# Resnet18

# %%
if extract_feature:
    import timm

    model = timm.create_model(
        'vgg19.tv_in1k',
        pretrained=True,
        num_classes=0,  # remove classifier nn.Linear
    )
    model = model.eval()

    # get model specific transforms (normalization, resize)
    data_config = timm.data.resolve_model_data_config(model)
    transforms = timm.data.create_transform(**data_config, is_training=False)

# %% [markdown]
# Test print image from Cifar 10

# %%
if extract_feature:
    test = unpickle('E:/Work/DS/Datasets/Raw/cifar-100-python/train')

    img = test[b'data'][0].reshape((3,32,32)).transpose(1,2,0).astype("uint8") # cow???
    label = test[b'filenames'][0]
    plt.imshow(img)
    plt.title(label)
    plt.show()

# %% [markdown]
# Load CIFAR 10

# %% [markdown]
# Process images from the cifar10 for the unwrapper

# %%
def process_minibatch(minibatch):
    batch_data = []
    for image in minibatch:
        # Convert to PIL image format
        img = Image.fromarray(image.reshape(3,32,32).transpose(1,2,0))
        # transform to model format and stack
        img = transforms(img)
        batch_data.append(img)
    batch_data = torch.stack(batch_data)
    # run through the resnet
    processed_data = model(batch_data)
    return processed_data

# %%
def feature_extraction(file, is_train = False):

    output_df = pd.DataFrame(columns=['Class'])

    MINIBATCH_SIZE = 200


    for k,batch in enumerate(file):
        print('processing batch', k+1)
        # get images
        images = batch[b'data']
        labels = batch[b'fine_labels']
        # Convert the list of images to a batch tensor
        if is_train:
            NUMBER_MINIBATCH = 50000/MINIBATCH_SIZE
        else:
            NUMBER_MINIBATCH = 10000/MINIBATCH_SIZE
        for i in range(0,int(NUMBER_MINIBATCH)):
            print('processing minibatch %d out of %d' %(i+1 , int(NUMBER_MINIBATCH)))
            minibatch = images[i*MINIBATCH_SIZE:(i+1)*MINIBATCH_SIZE]

            # get features and put into df format
            minibatch_output = process_minibatch(minibatch)
            minibatch_output_df = pd.DataFrame(minibatch_output.detach().numpy(), columns=[f'features_{i}' for i in range(4096)])
            minibatch_output_df['Class'] = labels[i*MINIBATCH_SIZE:(i+1)*MINIBATCH_SIZE]

            output_df = pd.concat([output_df, minibatch_output_df], ignore_index=True)
    return output_df

# %%
import pandas as pd
if extract_feature:
    cifar100 = [unpickle('E:/Work/DS/Datasets/Raw/cifar-100-python/train')]
    train = feature_extraction(cifar100, is_train = True)
    train.to_csv('extracted_features_train.csv', index = False)
else:
    train = pd.read_csv('extracted_features_train.csv')
# Out:
# processing batch 1
# processing minibatch 1 out of 250
# processing minibatch 2 out of 250
# processing minibatch 3 out of 250
# processing minibatch 4 out of 250
# processing minibatch 5 out of 250
# processing minibatch 6 out of 250
# processing minibatch 7 out of 250
# processing minibatch 8 out of 250
# processing minibatch 9 out of 250
# processing minibatch 10 out of 250
# processing minibatch 11 out of 250
# processing minibatch 12 out of 250
# processing minibatch 13 out of 250
# processing minibatch 14 out of 250
# processing minibatch 15 out of 250
# processing minibatch 16 out of 250
# processing minibatch 17 out of 250
# processing minibatch 18 out of 250
# processing minibatch 19 out of 250
# processing minibatch 20 out of 250
# processing minibatch 21 out of 250
# processing minibatch 22 out of 250
# processing minibatch 23 out of 250
# processing minibatch 24 out of 250
# processing minibatch 25 out of 250
# processing minibatch 26 out of 250
# processing minibatch 27 out of 250
# processing minibatch 28 out of 250
# processing minibatch 29 out of 250
# processing minibatch 30 out of 250
# processing minibatch 31 out of 250
# processing minibatch 32 out of 250
# processing minibatch 33 out of 250
# processing minibatch 34 out of 250
# processing minibatch 35 out of 250
# processing minibatch 36 out of 250
# processing minibatch 37 out of 250
# processing minibatch 38 out of 250
# processing minibatch 39 out of 250
# processing minibatch 40 out of 250
# processing minibatch 41 out of 250
# processing minibatch 42 out of 250
# processing minibatch 43 out of 250
# processing minibatch 44 out of 250
# processing minibatch 45 out of 250
# processing minibatch 46 out of 250
# processing minibatch 47 out of 250
# processing minibatch 48 out of 250
# processing minibatch 49 out of 250
# processing minibatch 50 out of 250
# processing minibatch 51 out of 250
# processing minibatch 52 out of 250
# processing minibatch 53 out of 250
# processing minibatch 54 out of 250
# processing minibatch 55 out of 250
# processing minibatch 56 out of 250
# processing minibatch 57 out of 250
# processing minibatch 58 out of 250
# processing minibatch 59 out of 250
# processing minibatch 60 out of 250
# processing minibatch 61 out of 250
# processing minibatch 62 out of 250
# processing minibatch 63 out of 250
# processing minibatch 64 out of 250
# processing minibatch 65 out of 250
# processing minibatch 66 out of 250
# processing minibatch 67 out of 250
# processing minibatch 68 out of 250
# processing minibatch 69 out of 250
# processing minibatch 70 out of 250
# processing minibatch 71 out of 250
# processing minibatch 72 out of 250
# processing minibatch 73 out of 250
# processing minibatch 74 out of 250
# processing minibatch 75 out of 250
# processing minibatch 76 out of 250
# processing minibatch 77 out of 250
# processing minibatch 78 out of 250
# processing minibatch 79 out of 250
# processing minibatch 80 out of 250
# processing minibatch 81 out of 250
# processing minibatch 82 out of 250
# processing minibatch 83 out of 250
# processing minibatch 84 out of 250
# processing minibatch 85 out of 250
# processing minibatch 86 out of 250
# processing minibatch 87 out of 250
# processing minibatch 88 out of 250
# processing minibatch 89 out of 250
# processing minibatch 90 out of 250
# processing minibatch 91 out of 250
# processing minibatch 92 out of 250
# processing minibatch 93 out of 250
# processing minibatch 94 out of 250
# processing minibatch 95 out of 250
# processing minibatch 96 out of 250
# processing minibatch 97 out of 250
# processing minibatch 98 out of 250
# processing minibatch 99 out of 250
# processing minibatch 100 out of 250
# processing minibatch 101 out of 250
# processing minibatch 102 out of 250
# processing minibatch 103 out of 250
# processing minibatch 104 out of 250
# processing minibatch 105 out of 250
# processing minibatch 106 out of 250
# processing minibatch 107 out of 250
# processing minibatch 108 out of 250
# processing minibatch 109 out of 250
# processing minibatch 110 out of 250
# processing minibatch 111 out of 250
# processing minibatch 112 out of 250
# processing minibatch 113 out of 250
# processing minibatch 114 out of 250
# processing minibatch 115 out of 250
# processing minibatch 116 out of 250
# processing minibatch 117 out of 250
# processing minibatch 118 out of 250
# processing minibatch 119 out of 250
# processing minibatch 120 out of 250
# processing minibatch 121 out of 250
# processing minibatch 122 out of 250
# processing minibatch 123 out of 250
# processing minibatch 124 out of 250
# processing minibatch 125 out of 250
# processing minibatch 126 out of 250
# processing minibatch 127 out of 250
# processing minibatch 128 out of 250
# processing minibatch 129 out of 250
# processing minibatch 130 out of 250
# processing minibatch 131 out of 250
# processing minibatch 132 out of 250
# processing minibatch 133 out of 250
# processing minibatch 134 out of 250
# processing minibatch 135 out of 250
# processing minibatch 136 out of 250
# processing minibatch 137 out of 250
# processing minibatch 138 out of 250
# processing minibatch 139 out of 250
# processing minibatch 140 out of 250
# processing minibatch 141 out of 250
# processing minibatch 142 out of 250
# processing minibatch 143 out of 250
# processing minibatch 144 out of 250
# processing minibatch 145 out of 250
# processing minibatch 146 out of 250
# processing minibatch 147 out of 250
# processing minibatch 148 out of 250
# processing minibatch 149 out of 250
# processing minibatch 150 out of 250
# processing minibatch 151 out of 250
# processing minibatch 152 out of 250
# processing minibatch 153 out of 250
# processing minibatch 154 out of 250
# processing minibatch 155 out of 250
# processing minibatch 156 out of 250
# processing minibatch 157 out of 250
# processing minibatch 158 out of 250
# processing minibatch 159 out of 250
# processing minibatch 160 out of 250
# processing minibatch 161 out of 250
# processing minibatch 162 out of 250
# processing minibatch 163 out of 250
# processing minibatch 164 out of 250
# processing minibatch 165 out of 250
# processing minibatch 166 out of 250
# processing minibatch 167 out of 250
# processing minibatch 168 out of 250
# processing minibatch 169 out of 250
# processing minibatch 170 out of 250
# processing minibatch 171 out of 250
# processing minibatch 172 out of 250
# processing minibatch 173 out of 250
# processing minibatch 174 out of 250
# processing minibatch 175 out of 250
# processing minibatch 176 out of 250
# processing minibatch 177 out of 250
# processing minibatch 178 out of 250
# processing minibatch 179 out of 250
# processing minibatch 180 out of 250
# processing minibatch 181 out of 250
# processing minibatch 182 out of 250
# processing minibatch 183 out of 250
# processing minibatch 184 out of 250
# processing minibatch 185 out of 250
# processing minibatch 186 out of 250
# processing minibatch 187 out of 250
# processing minibatch 188 out of 250
# processing minibatch 189 out of 250
# processing minibatch 190 out of 250
# processing minibatch 191 out of 250
# processing minibatch 192 out of 250
# processing minibatch 193 out of 250
# processing minibatch 194 out of 250
# processing minibatch 195 out of 250
# processing minibatch 196 out of 250
# processing minibatch 197 out of 250
# processing minibatch 198 out of 250
# processing minibatch 199 out of 250
# processing minibatch 200 out of 250
# processing minibatch 201 out of 250
# processing minibatch 202 out of 250
# processing minibatch 203 out of 250
# processing minibatch 204 out of 250
# processing minibatch 205 out of 250
# processing minibatch 206 out of 250
# processing minibatch 207 out of 250
# processing minibatch 208 out of 250
# processing minibatch 209 out of 250
# processing minibatch 210 out of 250
# processing minibatch 211 out of 250
# processing minibatch 212 out of 250
# processing minibatch 213 out of 250
# processing minibatch 214 out of 250
# processing minibatch 215 out of 250
# processing minibatch 216 out of 250
# processing minibatch 217 out of 250
# processing minibatch 218 out of 250
# processing minibatch 219 out of 250
# processing minibatch 220 out of 250
# processing minibatch 221 out of 250
# processing minibatch 222 out of 250
# processing minibatch 223 out of 250
# processing minibatch 224 out of 250
# processing minibatch 225 out of 250
# processing minibatch 226 out of 250
# processing minibatch 227 out of 250
# processing minibatch 228 out of 250
# processing minibatch 229 out of 250
# processing minibatch 230 out of 250
# processing minibatch 231 out of 250
# processing minibatch 232 out of 250
# processing minibatch 233 out of 250
# processing minibatch 234 out of 250
# processing minibatch 235 out of 250
# processing minibatch 236 out of 250
# processing minibatch 237 out of 250
# processing minibatch 238 out of 250
# processing minibatch 239 out of 250
# processing minibatch 240 out of 250
# processing minibatch 241 out of 250
# processing minibatch 242 out of 250
# processing minibatch 243 out of 250
# processing minibatch 244 out of 250
# processing minibatch 245 out of 250
# processing minibatch 246 out of 250
# processing minibatch 247 out of 250
# processing minibatch 248 out of 250
# processing minibatch 249 out of 250
# processing minibatch 250 out of 250

# %%
print(train.head())
print(train.shape)
# Out:
#   Class  features_0  features_1  features_2  features_3  features_4  \
# 0    19    0.184726     1.71737         0.0    4.866918    0.000000
# 1    29    0.000000     0.00000         0.0    3.010815    1.921054
# 2     0    0.000000     0.00000         0.0    3.359219    0.000000
# 3    11    0.000000     0.00000         0.0    3.758401    0.000000
# 4     1    0.000000     0.00000         0.0    3.980873    0.000000
#
#    features_5  features_6  features_7  features_8  ...  features_4086  \
# 0    0.000000    0.174963    0.000000    0.180414  ...            0.0
# 1    0.000000    0.237502    0.480713    0.000000  ...            0.0
# 2    0.458951    0.000000    1.304626    0.000000  ...            0.0
# 3    1.109995    0.000000    0.708492    0.000000  ...            0.0
# 4    0.251120    0.688527    0.000000    0.000000  ...            0.0
#
#    features_4087  features_4088  features_4089  features_4090  features_4091  \
# 0       0.000000       0.366237       0.000000       1.159384            0.0
# 1       0.000000       0.000000       1.092717       0.000000            0.0
# 2       0.724281       0.000000       0.000000       0.000000            0.0
# 3       0.256465       0.000000       0.685596       0.000000            0.0
# 4       0.000000       0.000000       0.000000       0.296806            0.0
#
#    features_4092  features_4093  features_4094  features_4095
# 0            0.0       0.000000            0.0            0.0
# 1            0.0       0.712283            0.0            0.0
# 2            0.0       0.261319            0.0            0.0
# 3            0.0       0.000000            0.0            0.0
# 4            0.0       0.568018            0.0            0.0
#
# [5 rows x 4097 columns]
# (50000, 4097)

# %% [markdown]
# Do the same for test set

# %%
if extract_feature:
    cifar100_test = [unpickle('E:/Work/DS/Datasets/Raw/cifar-100-python/test')]
    test = feature_extraction(cifar100_test)
    test.to_csv('extracted_features_test.csv', index = False)
else:
    test = pd.read_csv('extracted_features_test.csv')
# Out:
# processing batch 1
# processing minibatch 1 out of 50
# processing minibatch 2 out of 50
# processing minibatch 3 out of 50
# processing minibatch 4 out of 50
# processing minibatch 5 out of 50
# processing minibatch 6 out of 50
# processing minibatch 7 out of 50
# processing minibatch 8 out of 50
# processing minibatch 9 out of 50
# processing minibatch 10 out of 50
# processing minibatch 11 out of 50
# processing minibatch 12 out of 50
# processing minibatch 13 out of 50
# processing minibatch 14 out of 50
# processing minibatch 15 out of 50
# processing minibatch 16 out of 50
# processing minibatch 17 out of 50
# processing minibatch 18 out of 50
# processing minibatch 19 out of 50
# processing minibatch 20 out of 50
# processing minibatch 21 out of 50
# processing minibatch 22 out of 50
# processing minibatch 23 out of 50
# processing minibatch 24 out of 50
# processing minibatch 25 out of 50
# processing minibatch 26 out of 50
# processing minibatch 27 out of 50
# processing minibatch 28 out of 50
# processing minibatch 29 out of 50
# processing minibatch 30 out of 50
# processing minibatch 31 out of 50
# processing minibatch 32 out of 50
# processing minibatch 33 out of 50
# processing minibatch 34 out of 50
# processing minibatch 35 out of 50
# processing minibatch 36 out of 50
# processing minibatch 37 out of 50
# processing minibatch 38 out of 50
# processing minibatch 39 out of 50
# processing minibatch 40 out of 50
# processing minibatch 41 out of 50
# processing minibatch 42 out of 50
# processing minibatch 43 out of 50
# processing minibatch 44 out of 50
# processing minibatch 45 out of 50
# processing minibatch 46 out of 50
# processing minibatch 47 out of 50
# processing minibatch 48 out of 50
# processing minibatch 49 out of 50
# processing minibatch 50 out of 50

# %%
print(test.head())
print(test.shape)
# Out:
#   Class  features_0  features_1  features_2  features_3  features_4  \
# 0    49    0.648974    0.490222         0.0    4.811389         0.0
# 1    33    0.165886    0.000000         0.0    4.052351         0.0
# 2    72    0.000000    0.481742         0.0    5.241817         0.0
# 3    51    0.000000    0.000000         0.0    4.051072         0.0
# 4    71    0.000000    0.000000         0.0    3.203792         0.0
#
#    features_5  features_6  features_7  features_8  ...  features_4086  \
# 0     0.00000    0.000000    0.046998         0.0  ...            0.0
# 1     0.09755    0.000000    0.000000         0.0  ...            0.0
# 2     0.00000    0.317117    0.000000         0.0  ...            0.0
# 3     0.12837    0.000000    0.000000         0.0  ...            0.0
# 4     0.00000    0.000000    0.390322         0.0  ...            0.0
#
#    features_4087  features_4088  features_4089  features_4090  features_4091  \
# 0            0.0       1.246985       0.864302        0.00000       0.000000
# 1            0.0       0.000000       0.000000        0.41996       0.000000
# 2            0.0       0.000000       0.000000        0.00000       0.000000
# 3            0.0       0.000000       0.000000        0.00000       0.000000
# 4            0.0       0.000000       0.000000        0.00000       0.042118
#
#    features_4092  features_4093  features_4094  features_4095
# 0       0.075688            0.0       1.735541            0.0
# 1       0.000000            0.0       0.283372            0.0
# 2       0.076335            0.0       1.170184            0.0
# 3       0.000000            0.0       0.000000            0.0
# 4       0.255442            0.0       0.000000            0.0
#
# [5 rows x 4097 columns]
# (10000, 4097)
